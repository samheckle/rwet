# %%
import random
import textwrap

newspaper = """
Dada was an informal international movement, with 
participants in Europe and North America. The 
beginnings of Dada correspond to the outbreak of 
World War I. For many participants, the movement 
was a protest against the bourgeois nationalist 
and colonialist interests, which many Dadaists 
believed were the root cause of the war, and 
against the cultural and intellectual 
conformity — in art and more broadly in 
society — that corresponded to the war."""

words = newspaper.split()
random.shuffle(words)

print(textwrap.fill(" ".join(words), 60))
# Out:
# informal the conformity the to were believed protest more
# and For and war. many — the colonialist against an which
# bourgeois against broadly beginnings war, movement North the
# in movement, many Dada the The that art and and was Dadaists
# I. nationalist the in of a Dada World intellectual cause
# America. was interests, — Europe correspond international
# root War with to participants corresponded society
# participants, cultural outbreak and of in the of

# %%
five_syllable = [
'amanuensis',
'belletristical',
'penetralia',
'superangelic',
'supercelestial',
'subterranean',
'tonsillectomy',
'appendectomy',
'momentarily',
'appendicitis',
'hypochondriac',
'peripatetic',
'excoriating',
'epistolary',
'circumambient',
'ethnogenesis',
'autological',
'choreography',
'choreographer',
'lexicology',
'thanatology',
'topological',
'craniometry',
'topographical',
'alphanumeric',
'teleportation',
'divinatory',
'alphabetical',
'geometrical',
'terminology',
'toponomastic',
'ecclesiastic',
'semiotician',
'neurohumoral',
'photoperiod',
'deconstructionist',
'poststructuralist',
'obligatory',
'deconstructionism',
'poststructuralism',
'textualizing',
'textuality',
'sexualizing',
'physiologist',
'disproportionate',
'equilateral',
'neurotypical',
'unharmonious',
'disharmonious',
'inharmonious',
'granularity',
'electropathy',
'linearity',
'specificity',
'elasticity',
'sanatorium',
'reconcilable',
'configuration',
'asphyxiation',
'upregulation',
'diffusivity',
'electrocution',
'nucleophile',
'electrophilic',
'unsymmetrical',
'dilapidated',
'dilapidation',
'tatterdemalion',
'vituperative',
'boustrophedonic',
'paradigmatic',
'incredulously',
'incredulity',
'expostulation',
'impropriety',
'indelicacy',
'indelicately',
'coefficiency',
'expansivity',
'unparasitized',
'Geometridae',
'endopterygote',
'conformational',
'verification',
'optimization',
'synchrocyclotron',
'accelerating',
'qualitatively',
'scholasticism',
'neologian',
'abacterial',
'neological',
'neologism',
'genethliacal',
'phthalocyanine',
'circulatory',
'nervomuscular',
'sadomasochist',
'interoceptive',
'exteroceptive',
'respiratory',
'reciprocally',
'pedagogical',
'analogously',
'orthographical',
'astrological',
'chronological',
'semiology',
'geological',
'geographical',
'multiplicity',
'phonological',
'authenticity',
'multifarious',
'typographical',
'electrochemist',
'autoerotic',
'masturbatory',
'convulsionary',
'pejoratively',
'adiaphora',
'adiaphoron',
'superannuate',
'adiaphorous',
'aprosexia',
'lepidopteral',
'acrocephalic',
'lepidopterous',
'inexplicable',
'unconventional',
'lepidopteran',
'lepidoptery',
'pachydermata',
'barometrical',
'hippopotamus',
'thermometrical',
'histological',
'polariscopic',
'rheological',
'uncalibrated',
'paradoxical',
'autosuggestion',
'agnotology',
'erroneously',
'miscegenative',
'miscegenetic',
'miscegenesis',
'edification',
'exegetical',
'interpretation',
'extrapolation',
'cohabitators',
'coagulation',
'peloponnesian',
'Peloponnesus',
'electrolysis',
'aggradational',
'degradational',
'degenerated',
'degenerately',
'degenerating',
'degeneracy',
'degenerative',
'degeneration',
'recapitulate',
'ethnomania',
'polarization',
'somnambulancy',
'hypnobatia',
'somnambulation',
'noctambulism',
'noctambulation',
'lunambulism',
'somnambulistic',
'spiritualism',
'pseudoaxial',
'approximately',
'overestimate',
'inconsistently',
'incongruity',
'singularity',
'underestimate',
'similarity',
'approximation',
'polynomial',
'perivertebral',
'ichthyology',
'perivisceral',
'intrathoracic',
'unresponsiveness',
'unapproachable',
'unattainable',
'inaccessible',
'invulnerable',
'deforestation',
'discoloration',
'insinuating',
'insinuated',
'insinuation',
'ingenuousness',
'insincerity',
'adulteration',
'sophisticated',
'adulterated',
'incontaminate',
'precipitation',
'contaminated',
'contamination',
'infanticidal',
'parasiticide',
'neurological',
'dermatology',
'cumulonimbus',
'cerebro-spinal',
'conductivity',
'superconductive',
'preganglionic',
'postganglionic',
'neurotransmission',
'iconographer',
'iconographic',
'iconography',
'iconoclasm',
'hallucination',
'hysterectomy',
'abortifacient',
'planetesimals',
'equilibrium',
'Alpha Centauri',
'gravitational',
'variable star',
'molecular cloud',
'interstellar cloud',
'spiral galaxy',
'cosmographical',
'interstellar space',
'heliospheric',
'Kuiper belt objects',
'circumbinary',
'trans-Neptunian',
'coloratura',
'galvanometer',
'psychedelia',
'electronica',
'electronical',
'ambivalency',
'electricity',
'incalculable',
'immeasurable',
'temporality',
'temporarily',
'perpetually',
'perpetuation',
'in perpetuum',
'perpetuity',
'indefinitely',
'indefinable',
'indescribable',
'systemization',
'systemically',
'probability',
'equivocation',
'ambiguity',
'double-entendre',
'verbification',
'antagonistic',
'henotheistic',
'henotheism',
'intralinguistic',
'extralinguistic',
'glossophobia',
'glossological',
'anaphylaxis',
'anaphylactic',
'photosensitive',
'Munchausen syndrome',
'munchausenism',
'homogeneous',
'conglomeration',
'incinerated',
'incineration',
'amalgamation',
'retaliation',
'elucidation',
'receptivity',
'flexibility',
'simplification',
'synchronization',
'continuation',
'interpolation',
'putrification',
'purification',
'modification',
'overcompensate',
'self-aggrandizement',
'unexcitable',
'homoerotic',
'lesbianism',
'apologetic',
'inconsistency',
'phallocentrism',
'logocentrism',
'phallogocentric',
'somnambulism',
'immortality',
'immorality',
'cannibalism',
'alienated',
'alienation',
'tuberculosis',
'alcoholism',
'illegitimate',
'inhabitancy',
'unstimulating',
'inhabitable',
'inhabitation',
'cohabitating',
'cohabitator',
'cohabitation',
'prevarication',
'inaccuracy',
'misunderstanding',
'monasticism',
'commercialism',
'disenfranchisement',
'anti-semitic',
'discrimination',
'polytheism',
'polytheistic',
'monotheistic',
'monotheism',
'expressionistic',
'impressionism',
'romanticism',
'exhilaration',
'enthusiastic',
'enthusiasm',
'figuratively',
'inebriated',
'intoxicated',
'Dionysia',
'Dionysiac',
'Dionysian',
'aphrodisia',
'aphrodisiac',
'explanatory',
'exploratory',
'expiatory',
'purgatorial',
'occidentally',
'curiosity',
'circuitously',
'circumnavigate',
'vesuvianite',
'predisposition',
'agnosticism',
'orientation',
'sexuality',
'concupiscential',
'abominably',
'abomination',
'contradictory',
'unequivocally',
'unambiguous',
'unequivocal',
'philosophical',
'analytical',
'mathematical',
'astronomical',
'parenthetical',
'anatomical',
'psychosynthesis',
'anthropocentric',
'versification',
'praxeology',
'pandiculating',
'etiolation',
'cucurbitaceous',
'vivisepulture',
'epeolatry',
'rhapsodomancy',
'leucomelanous',
'auriculated',
'deus ex machina',
'cephalomancy',
'apatheism',
'psychomachia',
'artemisia',
'inamorata',
'dendrological',
'academia',
'traditionally',
'serpent-deity',
'mediocrity',
'apotheosis',
'exsanguination',
'archeology',
'sociology',
'anthropology',
'philological',
'cannibalistic',
'iconoclastic',
'parsimonious',
'prognosticator',
'prognostication',
'etiologic',
'abnormality',
'unusually',
'anachronism',
'normativity',
'somatization',
'deleterious',
'misoneistic',
'heterotrophic',
'inappropriate',
'malapropism',
'concomitancy',
'intoxication',
'inebriation',
'mutuality',
'atomicity',
'equivalency',
'pulchritudinous',
'teleology',
'unsaturated',
'desaturation',
'reactivity',
'solubility',
'decomposition',
'compartmentalize',
'metaphysical',
'pathophobia',
'experimental',
'metrorrhagia',
'inefficacy',
'effeminacy',
'inequality',
'intersexual',
'homosexual',
'asymmetrical',
'emasculation',
'dysmenorrhea',
'catamenia',
'menorrhagia',
'victimization',
'nymphomania',
'psychasthenia',
'neurasthenia',
'dissociation',
'psychological',
'hypochondria',
'cyberchondriac',
'contraindicate',
'anthropogeny',
'postmodernism',
'postcolonial',
'acculturation',
'isopraxism',
'eschatology',
'ontological',
'exacerbation',
'etiology',
'echolalia',
'hagiography',
'glossolalia',
'interdigitate',
'axiology',
'auxanometer',
'charientism',
'cacophemism',
'etymology',
'neuro- linguistic',
'autochthonously',
'palingenesis',
'metempsychosis',
'multiplication',
'photosynthesis',
'chemosynthesis',
'inflorescences',
'exenteration',
'evisceration',
'ameliorate',
'lackadaisical',
'variegated',
'kaleidoscopic',
'amplexicauline',
'stoloniferous',
'artemisinin',
'legerdemain',
'logodaedaly',
'cotoneaster',
'macrocephaly',
'macrocephalous',
'macrocephalic',
'dicotyledon',
'parthenogenic',
'morphological',
'monocotyloid',
'iatrochemist',
'apophenia',
'spagyrically',
'inexorably',
'extra textual',
'androgenesis',
'concatenation',
'phylogenesis',
'ontogenesis'
]

# %%
random.choice(five_syllable)
# Out:
# 'phrontisterionwas'

# %%
sal_adjs = [
    "Beloved",
    "Darling",
    "Dear",
    "Dearest",
    "Fanciful",
    "Honey"]
sal_nouns = [
    "Chickpea",
    "Dear",
    "Duck",
    "Jewel",
    "Love",
    "Moppet",
    "Sweetheart"
]
adjs = [
    'adorable',
'adventurous',
'aggressiveagreeable',
'alert',
'aliveamused',
'angry',
'annoyedannoying',
'anxious',
'arrogantashamed',
'attractive',
'averageawful',
'bad',
'beautifulbetter',
'bewildered',
'blackbloody',
'blue',
'blue-eyedblushing',
'bored',
'brainybrave',
'breakable',
'brightbusy',
'calm',
'carefulcautious',
'charming',
'cheerfulclean',
'clear',
'clevercloudy',
'clumsy',
'colorfulcombative',
'comfortable',
'concernedcondemned',
'confused',
'cooperativecourageous',
'crazy',
'creepycrowded',
'cruel',
'curiouscute',
'dangerous',
'darkdead',
'defeated',
'defiantdelightful',
'depressed',
'determineddifferent',
'difficult',
'disgusteddistinct',
'disturbed',
'dizzydoubtful',
'drab',
'dull'
]
nouns = [
'time',
'person',
'year',
'way',
'day',
'thing',
'man',
'world',
'life',
'hand',
'part',
'child',
'eye',
'woman',
'place',
'work',
'week',
'case',
'point',
'government',
'company',
'number',
'group',
'problem',
'fact'
]
advs = [
'boldly',
'bravely',
'brightly',
'cheerfully',
'deftly',
'devotedly',
'eagerly',
'elegantly',
'faithfully',
'fortunately',
'gleefully',
'gracefully',
'happily',
'honestly',
'innocently',
'kindly',
'merrily',
'obediently',
'perfectly',
'politely',
'powerfully',
'safely',
'victoriously',
'warmly',
'vivaciously'
]
verbs = [
   'be',
'have',
'do',
'say',
'get',
'make',
'go',
'know',
'take',
'see',
'come',
'think',
'look',
'want',
'give',
'use',
'find',
'tell',
'ask',
'work',
'seem',
'feel',
'try',
'leave',
'call'

]

# %%
# textwrap library used to "wrap" the text at a particular length
import textwrap

# inside this loop, build the phrases. strachey implemented "short" phrases
# and "long" phrases; two or more "short" phrases in a row have special
# formatting rules, so we need to know what the last phrase kind was in
# order to generate the output.
history = []
body = ""
for i in range(5):
    kind = random.choice(["short", "long"])
    if kind == "long":
        # adjectives and adverbs will be present only 50% of the time
        line = " ".join([
            "My",
            random.choice([random.choice(adjs), ""]),
            random.choice(nouns),
            random.choice([random.choice(advs), ""]),
            random.choice(verbs),
            "your",
            random.choice([random.choice(adjs), ""]),
            random.choice(nouns)])
        body += line
    else:
        adj_noun = random.choice(adjs) + " " + random.choice(nouns)
        # if the last phrase was "short," use truncated form
        if len(history) > 0 and history[-1] == "short":
            body += ": my " + adj_noun
        else:
            body += "You are my " + adj_noun
    body += ". "
    history.append(kind)
# clean up output
body = body.replace("  ", " ")
body = body.replace(". :", ":")
# put everything together
output += textwrap.fill(body, 60)
output += "\n\nYours " + random.choice(advs) + ",\n"
output += "M.U.C."
print(output)
# Out:
# Dear Duck,
#
# My curious ardour fervently loves your craving. You are my
# passionate thirst: my covetous eagerness: my wistful
# enthusiasm: my loving thirst.
#
# Yours ardently,
# M.U.C.My unsatisfied little liking affectionately attracts your
# winning sympathy. My infatuation ardently woos your
# beautiful desire. You are my unsatisfied desire. My
# adoration tenderly yearns for your breathless hunger. You
# are my breathless fellow feeling.
#
# Yours fondly,
# M.U.C.

# %%
# textwrap library used to "wrap" the text at a particular length
import textwrap

# inside this loop, build the phrases. strachey implemented "short" phrases
# and "long" phrases; two or more "short" phrases in a row have special
# formatting rules, so we need to know what the last phrase kind was in
# order to generate the output.
body = ""
for i in range(5):
    if kind == "long":
        # adjectives and adverbs will be present only 50% of the time
        line = " ".join([
            "My",
            random.choice([random.choice(adjs), ""]),
            random.choice(nouns),
            random.choice([random.choice(advs), ""]),
            random.choice(verbs),
            "your",
            random.choice([random.choice(adjs), ""]),
            random.choice(nouns)])
        body += line
    body += ". "
# clean up output
body = body.replace("  ", " ")
body = body.replace(". :", ":")
# put everything together
output = textwrap.fill(body, 20)
print(output)
# Out:
# My fondest hunger
# impatiently longs
# for your wish. My
# fervent fervour
# curiously pines for
# your being. My
# craving pants for
# your craving
# rapture. My
# unsatisfied hunger
# seductively woos
# your affectionate
# burning. My
# affection curiously
# longs for your wish.

# %%
# textwrap library used to "wrap" the text at a particular length
import textwrap

# inside this loop, build the phrases. strachey implemented "short" phrases
# and "long" phrases; two or more "short" phrases in a row have special
# formatting rules, so we need to know what the last phrase kind was in
# order to generate the output.
body = ""
for i in range(5):
    if kind == "long":
        # adjectives and adverbs will be present only 50% of the time
        line = " ".join([
            "My",
            random.choice([random.choice(adjs), ""]),
            random.choice(nouns),
            random.choice([random.choice(advs), ""]),
            random.choice(verbs),
            "your",
            random.choice([random.choice(adjs), ""]),
            random.choice(nouns)])
        body += line
    body += ". "
# clean up output
body = body.replace("  ", " ")
body = body.replace(". :", ":")
# put everything together
output = textwrap.fill(body, 20)
print(output)
# Out:
# My affection
# attracts your eager
# passion. My wish
# beautifully pants
# for your sweet
# fancy. My little
# liking thirsts for
# your fellow feeling.
# My enchantment
# anxiously tempts
# your burning
# fondness. My being
# attracts your
# longing.

# %%
# textwrap library used to "wrap" the text at a particular length
import textwrap

# inside this loop, build the phrases. strachey implemented "short" phrases
# and "long" phrases; two or more "short" phrases in a row have special
# formatting rules, so we need to know what the last phrase kind was in
# order to generate the output.
body = ""
for i in range(5):
        # adjectives and adverbs will be present only 50% of the time
    line = " ".join([
        random.choice([random.choice(adjs), ""]),
        random.choice(nouns),
        random.choice([random.choice(advs), ""]),
        random.choice(verbs),
        random.choice([random.choice(adjs), ""]),
        random.choice(nouns),
        "\n"])
    body += line + '\n'
    space = random.randint(1, 9)
    for i in range(space):
        body += "    \n"
# clean up output
# body = body.replace("  ", " ")
body = body.replace(". :", ":")
# put everything together
output = textwrap.fill(body, 30)
print(output)
# Out:
#  wish burningly attracts
# devotion
# lovesick devotion  adores
# hunger
# craving little liking
# impatiently hungers for
# lovesick ambition
# sympathy  woos burning fellow
# feeling
# covetous lust passionately
# hopes for  being
