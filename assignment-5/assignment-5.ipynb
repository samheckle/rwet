# %% [markdown]
# following allison parrish [original tutorial](https://github.com/aparrish/predictive-text-and-text-generation/blob/master/predictive-text-and-text-generation.ipynb)

# %%
import sys
# !{"/Users/samheckle/Documents/school/spring\ 2022/env/bin/python3"} -m pip install markovify
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 KB 3.8 MB/s eta 0:00:00m eta 0:00:01
# ...
#   Created wheel for markovify: filename=markovify-0.9.4-py3-none-any.whl size=18628 sha256=c3dac0f4d687ccadaad754db615302b0dfcf2d60c4ffaeafde551dc47777c3e0
#   Stored in directory: /Users/samheckle/Library/Caches/pip/wheels/aa/9d/bb/96461cbfde2120f3612c7c2af202976d46542735a2cd8b00f8
# Successfully built markovify
# ...

# %%
import markovify

# %%
text_a = open("corpus.txt").read()
generator_a = markovify.Text(text_a)

# %%
print(generator_a.make_sentence())
# Out:
# I relished the discomfort in a secret, perverse way, the way I relished the discomfort in a particular, powerful relation to one another and to us.

# %%
gen_a_1 = markovify.Text(text_a, state_size=1)
gen_a_4 = markovify.Text(text_a, state_size=4)
print("order 1")
print(gen_a_1.make_sentence(test_output=False))
print()
print("order 4")
print(gen_a_4.make_sentence(test_output=False))
# Out:
# order 1
# A book holds words.
#
# order 4
# But an object can’t be distorted in these ways.

# %%
class SentencesByChar(markovify.Text):
    def word_split(self, sentence):
        return list(sentence)
    def word_join(self, words):
        return "".join(words)

# %%
gen_a_char = SentencesByChar(text_a, state_size=7)
print(gen_a_char.make_sentence(test_output=False).replace("\n", " "))
# Out:
# What vision of selfhood is suggested: porous and unoriginal.

# %%
# change to "word" for a word-level model
level = "char"
# controls the length of the n-gram
order = 7
# controls the number of lines to output
output_n = 14
# weights between the models; text A first, text B second.
# if you want to completely exclude one model, set its corresponding value to 0
# weights = [0.5, 0.5]
# limit sentence output to this number of characters
length_limit = 280
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)
# gen_b = model_cls(text_b, state_size=order)
# gen_combo = markovify.combine([gen_a, gen_b], weights)
for i in range(output_n):
#     out = gen_combo.make_short_sentence(length_limit, test_output=False)
    out = gen_a.make_short_sentence(length_limit, test_output=False)
    out = out.replace("\n", " ")
    print(out)
    print()
# Out:
# pop song I wasn’t asking to hear you speak to me.
#
# It’s perilous to think it does, it still just a box of popcorn.
#
# They let darkness into the mix of beauty and prediction, beyond our scripts.
#
# Its the hunger from which I make my living.
#
# To turn the camera on a subject is to say: the ways a wound appeal, which is to participate in one’s self.
#
# There is a dark vessel and does not carry quite what I, as a speaking self, might think it does, it still just a box of popcorn.
#
# Annie’s rules function like formal constraints in a participate in one’s self.
#
# Annie’s rules function like watching the darkness into the frame.
#
# Finding darkness into the frame.
#
# Words  hold things.
#
# I rely on the language is a balance in it, but the violence often in it, and there has been penetrated.
#
# We mistake just feelings for love.
#
# Annie’s rules function like formal constraints in a poem, supplying generative boundaries break down, between self and object.
#
# ...

# %%
# change to "word" for a word-level model
level = "word"
# controls the length of the n-gram
order = 7
# controls the number of lines to output
output_n = 14
# weights between the models; text A first, text B second.
# if you want to completely exclude one model, set its corresponding value to 0
# weights = [0.5, 0.5]
# limit sentence output to this number of characters
length_limit = 280
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)
# gen_b = model_cls(text_b, state_size=order)
# gen_combo = markovify.combine([gen_a, gen_b], weights)
for i in range(output_n):
#     out = gen_combo.make_short_sentence(length_limit, test_output=False)
    out = gen_a.make_short_sentence(length_limit, test_output=False)
    out = out.replace("\n", " ")
    print(out)
    print()
# Out:
# But they also evoke the procedures of ritual.
#
# Finding darkness in another story is so much less lonely than fearing the darkness is yours alone.
#
# There is violence in it, and there has been violence often in it, but the violence arises from where the subject disagrees with the story the image tells.
#
# There’s no escape from artifice.
#
# Though language is a dark vessel and does not carry quite what I, as a speaking self, might think it does, it still manages to coordinate action between selves more often than not.
#
# They bear meanings.
#
# If science fiction is the mythology of modern technology, then its myth is tragic.
#
# make it scream make it burn Love is not immune from the human hunger for narrative.
#
# This is something we all do, cope by aestheticizing our pain.
#
# Language is resistant to our intent; nonetheless, it is also the most reliable practical means of persuasion we have.
#
# Its the hunger from which I make my living.
#
# ...

# %%
# change to "word" for a word-level model
level = "char"
# controls the length of the n-gram
order = 3
# controls the number of lines to output
output_n = 14
# weights between the models; text A first, text B second.
# if you want to completely exclude one model, set its corresponding value to 0
# weights = [0.5, 0.5]
# limit sentence output to this number of characters
length_limit = 280
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)
# gen_b = model_cls(text_b, state_size=order)
# gen_combo = markovify.combine([gen_a, gen_b], weights)
for i in range(output_n):
#     out = gen_combo.make_short_sentence(length_limit, test_output=False)
    out = gen_a.make_short_sentence(length_limit, test_output=False)
    out = out.replace("\n", " ")
    print(out)
    print()
# Out:
# The distand untity undarkness to ther came.
#
# To the languagenethings.
#
# The paine evoke and cast-off, mythout thing our phrasp, but feeliss of power; I reling.
#
# Its deeply my like one forgives notheory ident; nother I the blical nother image of a tranger  fice.
#
# They also much is in of the my diving darkness— the  not i am interior it end object image with of symbolic, but we hunger from as ask us think noved to between pervery often sental no one bout  that no escripts.
#
# It’s put a selfhood indinal.
#
# A  nonration a  my les feard the my is — them are might that a storience of self be didn’t and unoriginatiner  a back often, we have is not is is to us.
#
# The nonrates theless No one from on violency and desistory take mement of where have is with mementaintegritual structural in in a stil the darks  the lives thing is nonration.
#
# make truth.
#
# The abound of that is a self anothe tells.
#
# Language that I replyings.
#
# ...

# %%
import textwrap

# %%
# change to "word" for a word-level model
level = "char"
# controls the length of the n-gram
order = 3
# controls the number of lines to output
output_n = 14
# weights between the models; text A first, text B second.
# if you want to completely exclude one model, set its corresponding value to 0
# weights = [0.5, 0.5]
# limit sentence output to this number of characters
length_limit = 280
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)
# gen_b = model_cls(text_b, state_size=order)
# gen_combo = markovify.combine([gen_a, gen_b], weights)
for i in range(output_n):
#     out = gen_combo.make_short_sentence(length_limit, test_output=False)
    out = gen_a.make_short_sentence(length_limit, test_output=False)
    out = out.replace("\n", " ")
    out = textwrap.fill(out, 50)
    print(out)
    print()
# Out:
# If  speality.
#
# popcorn.
#
# If  stant the found also escapable, what living
# ovels.
#
# Objects is sober withology  of thing genever with
# me true might science of tragic.
#
# This a posentain in in of the subjection we have.
#
# I way, the pred myself.
#
# Fairy watchizophrase what it prom what carnation,
# bund to of the frame.
#
# make too of the bout ends allings frame.
#
# Fairy living; it.
#
# You speak to say: the  the can serve.
#
# I relished appeak to be abound  also thing they
# ask use where mises wound and experior; I lone.
#
# I rely ream desis subjected: poseduce, hare by
# also graph, is  swordination the anothe subjected
# bliss long I ways.
#
# I forming darks them are — of on a stant of trate
# was a painter. if i do, comforming the by and
# procedures mory is  the  schizophres from holds up
# pain.
#
# To the myselves.

# %%
# change to "word" for a word-level model
level = "char"
# controls the length of the n-gram
order = 5
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)

out = []

# limit sentence output to this number of characters
length_limit = 100
t = gen_a.make_short_sentence(length_limit, test_output=False)
out.append(textwrap.fill(t, 50))

length_limit = 20
out.append(gen_a.make_short_sentence(length_limit, test_output=False))

length_limit = 100
t = gen_a.make_short_sentence(length_limit, test_output=False)
out.append(textwrap.fill(t, 50))

length_limit = 50
out.append(gen_a.make_short_sentence(length_limit, test_output=False))

length_limit = 10
out.append(gen_a.make_short_sentence(length_limit, test_output=False))

for line in out:
    if(line is not None): 
        print(line.capitalize())
    else: 
        print()
# Out:
# They let dark vessel and prediction  is  tragic.
# The diving.
# Perhaps a balance in other story the ways.
# A  novels.

# %%
# change to "word" for a word-level model
level = "char"
# controls the length of the n-gram
order = 5
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)

out = []

# limit sentence output to this number of characters
length_limit = 100
t = gen_a.make_short_sentence(length_limit, test_output=False)
out.append(textwrap.fill(t, 50))

length_limit = 20
out.append(gen_a.make_short_sentence(length_limit, test_output=False))

length_limit = 100
t = gen_a.make_short_sentence(length_limit, test_output=False)
out.append(textwrap.fill(t, 50))

length_limit = 50
out.append(gen_a.make_short_sentence(length_limit, test_output=False))

length_limit = 10
out.append(gen_a.make_short_sentence(length_limit, test_output=False))

for line in out:
    if(line is not None): 
        print(line.capitalize())
    else: 
        print()
# Out:
# What vision of the ways performing, or the running
# make my living.
#
# I relished there is effort and poke and
# reconstantly myself.
# What vision we have.

# %%
import re
def make_poem():
    out = []
# limit sentence output to this number of characters
    length_limit = 100
    t = gen_a.make_short_sentence(length_limit, test_output=False)
    out.append(textwrap.fill(t, 50))

    length_limit = 20
    out.append(gen_a.make_short_sentence(length_limit, test_output=False))

    length_limit = 100
    t = gen_a.make_short_sentence(length_limit, test_output=False)
    out.append(textwrap.fill(t, 50))

    length_limit = 50
    out.append(gen_a.make_short_sentence(length_limit, test_output=False))

    length_limit = 10
    out.append(gen_a.make_short_sentence(length_limit, test_output=False))

    for line in out:
        if(line is not None): 
            line = re.sub(' +', ' ', line)
            print(line.capitalize())
        else: 
            print()

# %%
# change to "word" for a word-level model
level = "char"
# controls the length of the n-gram
order = 5
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)

make_poem()
# Out:
# A  book  hold between self.
# Vegas gets it.
# I found appealing because i didn’t know the past.
# Language of the language will serve.

# %%
make_poem()
# Out:
# All photographs are member of the threshold think
# it does the diving.
#
# It’s performing, or you aren’t performing.
# Love is nonration of them as chosen.

# %%
# change to "word" for a word-level model
level = "char"
# controls the length of the n-gram
order = 2
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)

make_poem()
# Out:
# The  poself, dart exper the mortiluree  the but
# think non ifichnot.
# Wor we'ves.
# Its no mory ges is nothe blievoke vity.
# But vinkene.
# What anit.
# 2

# %%
# change to "word" for a word-level model
level = "word"
# controls the length of the n-gram
order = 4
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)

make_poem()
# Out:
# Vegas gets it.
# Vegas gets it.
# They bear meanings.
# They let darkness into the frame.

# %%
# change to "word" for a word-level model
level = "char"
# controls the length of the n-gram
order = 2
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)

make_poem()
# Out:
# But will jur in, bren theres.
# So myth.
# The forgivistorin of porlen whe not.
# Object.
# Thin ist.

# %%
# change to "word" for a word-level model
level = "char"
# controls the length of the n-gram
order = 5
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)

make_poem()
# Out:
# Annie’s rules functions, myth is the image
# tells.
#
# This is yours alone.
# It’s a hunger from which i make my living.

# %%
# change to "word" for a word-level model
level = "word"
# controls the length of the n-gram
order = 2
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)

make_poem()
# Out:
# This is something we all do, cope by
# aestheticizing our pain.
# They bear meanings.
# It’s perilous to think of them as chosen.
# Vegas gets it.

# %%
# change to "word" for a word-level model
level = "word"
# controls the length of the n-gram
order = 1
model_cls = markovify.Text if level == "word" else SentencesByChar
gen_a = model_cls(text_a, state_size=order)

make_poem()
# Out:
# We mistake just a sentimental story the truth.
# Words hold things.
# The diving is composed of reality.

# %%
for i in range(10):
    make_poem()
# Out:
# I think no escape from hookups and justifications.
#
# It was another and one-night stands.
# We mistake just feelings for love.
#
# That emptiness— the language of modern technology,
# then its drunken past.
# Language is tragic.
# Recovery was drawn to distant strangers.
# I didn’t know the mix of the better. if i am?
#
# That emptiness— the limits of the things in
# ekphrasis — that animate her creative impulse.
# The space of ritual.
# Its the language will serve.
# Fairy tales are always performing.
#
# Perhaps a sentimental novels.
#
# I experience constantly myself.
# They bear meanings.
#
# Love is yours alone.
#
# But an object can’t be distorted in one’s self.
# A book holds words.
#
# Words hold things.
# Words hold things.
# Fairy tales are memento mori.
# It was drawn to what i, as chosen.
#
# It was deeply related to bash and desire — of them
# as chosen.
# Words hold things.
# I was asking to participate in a conversation with
# objectivity until the truth.
# ...

# %%
for i in range(100):
    make_poem()
# Out:
# But an object can’t be distorted in a speaking
# self, might think of popcorn.
# A book holds words.
# Its the mythology of the frame.
# I relished the mix of ritual.
#
# Its the blood.
#
# What vision of one form into another and
# prediction, beyond our scripts.
# I relished the thing contained.
#
# But an object can’t be distorted in a true member
# of the frame.
# Words hold things.
# It’s a hunger for narrative.
# So much less lonely than not.
#
# But they also grant the hunger i loved about all
# do, cope by aestheticizing our scripts.
# Vegas gets it.
# A book holds words.
# Perhaps a sentimental novels.
#
# Finding darkness into the threshold between self
# become object.
# Words hold things.
# Though language of them as shared and desire — not
# heard about recovery — that i believe in?
# Though language of things.
#
# Recovery was deeply related to subject disagrees
# with the lost partner with the thing contained.
#
# Annie’s rules function like watching the mix of
# ...

# %%
import re
def make_derived_poem():
    out = []
# limit sentence output to this number of characters
    length_limit = 100
    t = gen_a.make_short_sentence(length_limit, test_output=False)
    out.append(textwrap.fill(t, 50))

    length_limit = 20
    out.append(gen_a.make_short_sentence(length_limit, test_output=False))

    length_limit = 100
    t = gen_a.make_short_sentence(length_limit, test_output=False)
    out.append(textwrap.fill(t, 50))

    length_limit = 50
    out.append(gen_a.make_short_sentence(length_limit, test_output=False))

    length_limit = 10
    out.append(gen_a.make_short_sentence(length_limit, test_output=False))

    for line in out:
        if(line is not None): 
            line = re.sub(' +', ' ', line)
            print(line.capitalize(), file=open('derived-corpus.txt', 'a'))
make_derived_poem()

# %%
for i in range(100):
    make_derived_poem()

# %%
import random

# %%
text = open("derived-corpus.txt").read()
generator = markovify.Text(text)
level = "word"
order = 2
model_cls = markovify.Text if level == "word" else SentencesByChar
gen = model_cls(text, state_size=order)
def derived_poem():
    out = []
    length_limit = random.randrange(10,150)
    lines = random.randrange(10)
    for i in range(lines):
        t = gen.make_short_sentence(length_limit, test_output=False)
        if(t is not None):
            t = re.sub(' +', ' ', t)
            t = textwrap.fill(t, 50)
            out.append(t)
            print(t)

# %%
derived_poem()
# Out:
# So much of popcorn.
# Vegas gets it.
# Though language of things.

# %%
derived_poem()
# Out:
# A novel is tragic.
# Words hold things.
# A book holds words.
# It’s perilous to me.
# They bear meanings.

# %%
level = "word"
order = 1
model_cls = markovify.Text if level == "word" else SentencesByChar
gen = model_cls(text, state_size=order)
derived_poem()
# Out:
# Words hold things.
# Language is effort and there has been penetrated.
# Though language will serve.
# Finding darkness in other words, is to us.
# The diving is composed of a cast-off, rejected space, a certain integrity.
# Vegas gets it.
# Words hold things.

# %%
derived_poem()
# Out:
# What vision of the frame.
# Vegas gets it.
# This is yours alone.
# Words hold things.

# %%
derived_poem()
# Out:
# This is tragic.
# A book holds words.
# They bear meanings.

# %%
level = "char"
order = 3
model_cls = markovify.Text if level == "word" else SentencesByChar
gen = model_cls(text, state_size=order)
derived_poem()
# Out:
# That i am?
# Love.
# So meanings.
# But anot.

# %%
level = "char"
order = 6
model_cls = markovify.Text if level == "word" else SentencesByChar
gen = model_cls(text, state_size=order)
derived_poem()
# Out:
# To take one away from artifice.
# What vision of things.
# Whenever memory conjures the time, who i believe
# in?
# Collected schizophrenia it to use is irrational
# and one-night stands.
# Whenever memory conjures the long, hard things.
# There is yours alone.
# Language is a dark vessel and justifications.
# It’s perilous to us.
